# %% [markdown]
# **In this Notebook we will Test YOLO on segmented imaged detected using Detectron2**

# %%
# !pip install ultralytics

# %%
#import libs
from ultralytics import YOLO
import os
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Load the YOLO model for pose estimation
model = YOLO('yolov8n-pose.pt')
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 63.8MB/s]

# %% [markdown]
# **The Detection on segmented images**

# %%
#data we want to use to predict the pose
img_test_folder="/content/drive/MyDrive/imgs_test_set/Detectron2_result/segmented_humans"
imgs=[i for i in os.listdir(img_test_folder) if i.endswith(('.jpg', '.jpeg', '.png'))]

# %%
for img in imgs:
  #Full path
  img_full_path=os.path.join(img_test_folder,img)
  # Predict with the model
  results = model(img_full_path, save=True)
  print(f"Processed {img}")
# Out:
# image 1/1 /content/drive/MyDrive/imgs_test_set/Detectron2_result/segmented_humans/1_person_0_segmentation.jpg: 640x544 2 persons, 510.2ms
# Speed: 33.4ms preprocess, 510.2ms inference, 55.5ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/pose/predict
# Processed 1_person_0_segmentation.jpg
# image 1/1 /content/drive/MyDrive/imgs_test_set/Detectron2_result/segmented_humans/1_person_1_segmentation.jpg: 640x544 1 person, 340.1ms
# Speed: 4.4ms preprocess, 340.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/pose/predict
# Processed 1_person_1_segmentation.jpg
# image 1/1 /content/drive/MyDrive/imgs_test_set/Detectron2_result/segmented_humans/1_person_2_segmentation.jpg: 640x544 1 person, 311.1ms
# Speed: 3.7ms preprocess, 311.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/pose/predict
# Processed 1_person_2_segmentation.jpg
# ...

# %% [markdown]
# the output contains informations such as the number of human detected , Image size ect ...

# %% [markdown]
# **Note : by defaults runs folder will be created to save results**

# %%
output_folder='/content/runs/pose/predict'

# %%
# Get a list of all image files in the folder
image_files = [f for f in os.listdir(output_folder) if f.endswith(('.jpg', '.jpeg', '.png'))]
for image_file in image_files:
    # Construct the full path to the image
    image_path = os.path.join(output_folder, image_file)

    # Load and display the image
    img = mpimg.imread(image_path)
    plt.imshow(img)
    plt.axis('off')  # Hide axis
    plt.title(image_file)  # Display the image filename as the title
    plt.show()

# %% [markdown]
# Even though we loaded the yolo pose model , the detection model is included
